# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
import os

# %%
def drawing(generation, profile_number): 
    
    profile_root = 'profiles\gen' + str(generation) + '\profile' + str(profile_number) + '.txt'
    
    profile_name = 'Generación ' + str(generation) + ', perfil ' + str(profile_number)
 
    datos = np.loadtxt(profile_root, skiprows=3, usecols=[0,1])
    
    plt.figure(num=None, figsize=(15, 5), dpi=80, facecolor='w', edgecolor='k')
    plt.title (profile_name)
    plt.ylim(-0.15, 0.15)
    plt.xlim(-0.05, 1.05)
    plt.plot(datos[:,0], datos[:,1])
    plt.gca().set_aspect(1)
    
    
    if not os.path.exists('graficos'):
        os.makedirs('graficos')
        
        
    nombre_grafico = 'graficos\gen' + str(generation) + 'profile' + str(profile_number) + '.png'
    plt.savefig(nombre_grafico)

# %%
for i in np.arange(0,19,1):
    drawing(i,1)
    drawing(i,2)
# Out:
# C:\Anaconda3\lib\site-packages\matplotlib\pyplot.py:423: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_num_figures`).
#   max_open_warning, RuntimeWarning)
